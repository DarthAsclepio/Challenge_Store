# %% [markdown]
# <a href="https://colab.research.google.com/github/DarthAsclepio/Challenge_Store/blob/main/AluraStoreChallenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_total_tienda1 = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()

# %%
print(f"Ingreso total Tienda 1: {ingreso_total_tienda1:,.2f}")
print(f"Ingreso total Tienda 2: {ingreso_total_tienda2:,.2f}")
print(f"Ingreso total Tienda 3: {ingreso_total_tienda3:,.2f}")
print(f"Ingreso total Tienda 4: {ingreso_total_tienda4:,.2f}")
# Out:
# Ingreso total Tienda 1: 1,150,880,400.00
# Ingreso total Tienda 2: 1,116,343,500.00
# Ingreso total Tienda 3: 1,098,019,600.00
# Ingreso total Tienda 4: 1,038,375,700.00

# %%
ingresos_totales = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingreso Total': [ingreso_total_tienda1, ingreso_total_tienda2, \
                      ingreso_total_tienda3, ingreso_total_tienda4]
})

plt.figure(figsize=(4, 6))
sns.barplot(x='Tienda', y='Ingreso Total', data=ingresos_totales, palette='viridis')
plt.title('Ingreso Total por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total (COP)')
plt.ticklabel_format(style='plain', axis='y')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4207034992.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tienda', y='Ingreso Total', data=ingresos_totales, palette='viridis')

# %%
total_global_ventas = ingresos_totales['Ingreso Total'].sum()

ingresos_totales['Porcentaje'] = (ingresos_totales['Ingreso Total'] / total_global_ventas) * 100

plt.figure(figsize=(8, 8))
plt.pie(ingresos_totales['Porcentaje'],
        labels=ingresos_totales['Tienda'],
        autopct='%1.1f%%',
        startangle=90,
        colors=plt.cm.tab10.colors)
plt.title('Distribución Porcentual de Ventas por Tienda')
plt.axis('equal')
# Out:
# (np.float64(-1.0999997899608607),
#  np.float64(1.099998023350979),
#  np.float64(-1.099999808360784),
#  np.float64(1.099999990874323))

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda['Categoría del Producto'].unique()
# Out:
# array(['Electrónicos', 'Muebles', 'Juguetes', 'Electrodomésticos',
#        'Artículos para el hogar', 'Deportes y diversión', 'Libros',
#        'Instrumentos musicales'], dtype=object)

# %%
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum()
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum()
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum()
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum()

print("\nVentas por Categoría en Tienda 1:")
print(ventas_por_categoria_tienda1)

print("\nVentas por Categoría en Tienda 2:")
print(ventas_por_categoria_tienda2)

print("\nVentas por Categoría en Tienda 3:")
print(ventas_por_categoria_tienda3)

print("\nVentas por Categoría en Tienda 4:")
print(ventas_por_categoria_tienda4)
# Out:
# Ventas por Categoría en Tienda 1:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64
#
# Ventas por Categoría en Tienda 2:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64
#
# Ventas por Categoría en Tienda 3:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# ...

# %%
ventas_por_categoria = pd.DataFrame({
    'Tienda 1': ventas_por_categoria_tienda1,
    'Tienda 2': ventas_por_categoria_tienda2,
    'Tienda 3': ventas_por_categoria_tienda3,
    'Tienda 4': ventas_por_categoria_tienda4
})

ventas_por_categoria = ventas_por_categoria.reset_index()

ventas_por_categoria.rename(columns={'index': 'Categoría del Producto'}, inplace=True);

ventas_melted = ventas_por_categoria.melt(id_vars='Categoría del Producto', var_name='Tienda', value_name='Ventas')

plt.figure(figsize=(7, 4))
sns.barplot(x='Categoría del Producto', y='Ventas', hue='Tienda', data=ventas_melted)
plt.title('Ventas por Tienda y por Categoría de Producto')
plt.xlabel('Categoría del Producto')
plt.ylabel('Ventas (COP)')
plt.xticks(rotation=45, ha='right')
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

# %%
print(f"Calificación promedio Tienda 1: {calificacion_promedio_tienda1:.2f}")
print(f"Calificación promedio Tienda 2: {calificacion_promedio_tienda2:.2f}")
print(f"Calificación promedio Tienda 3: {calificacion_promedio_tienda3:.2f}")
print(f"Calificación promedio Tienda 4: {calificacion_promedio_tienda4:.2f}")
# Out:
# Calificación promedio Tienda 1: 3.98
# Calificación promedio Tienda 2: 4.04
# Calificación promedio Tienda 3: 4.05
# Calificación promedio Tienda 4: 4.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

calificaciones_promedio = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Calificación Promedio': [calificacion_promedio_tienda1, calificacion_promedio_tienda2,
                              calificacion_promedio_tienda3, calificacion_promedio_tienda4]
})

plt.figure(figsize=(3, 2))
sns.barplot(x='Tienda', y='Calificación Promedio', data=calificaciones_promedio, palette='Greens_d')
plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.ylim(0, 5)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-615428925.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tienda', y='Calificación Promedio', data=calificaciones_promedio, palette='Greens_d')

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
print('--- Productos más vendidos por tienda ---')

for i, store_df in enumerate([tienda, tienda2, tienda3, tienda4]):
    most_sold_products = store_df.groupby('Producto')['Precio'].sum().nlargest(3)
    print(f'\nTienda {i+1} (Top 3):')
    print(most_sold_products)

print('\n--- Productos menos vendidos por tienda ---')

for i, store_df in enumerate([tienda, tienda2, tienda3, tienda4]):
    least_sold_products = store_df.groupby('Producto')['Precio'].sum().nsmallest(3)
    print(f'\nTienda {i+1} (3 Menos vendidos):')
    print(least_sold_products)
# Out:
# --- Productos más vendidos por tienda ---
#
# Tienda 1 (Top 3):
# Producto
# TV LED UHD 4K    142150200.0
# Refrigerador     112143300.0
# Iphone 15         97902200.0
# Name: Precio, dtype: float64
#
# Tienda 2 (Top 3):
# Producto
# Iphone 15        113225800.0
# TV LED UHD 4K    103375000.0
# Refrigerador      97632500.0
# Name: Precio, dtype: float64
#
# Tienda 3 (Top 3):
# Producto
# Refrigerador     99889700.0
# TV LED UHD 4K    96669100.0
# Iphone 15        93225700.0
# Name: Precio, dtype: float64
#
# Tienda 4 (Top 3):
# Producto
# Iphone 15        96697500.0
# TV LED UHD 4K    90295300.0
# Smart TV         82790400.0
# Name: Precio, dtype: float64
#
# --- Productos menos vendidos por tienda ---
#
# Tienda 1 (3 Menos vendidos):
# Producto
# Cuerda para saltar    652800.0
# Dinosaurio Rex        688900.0
# Cubo mágico 8x8       696900.0
# Name: Precio, dtype: float64
#
# Tienda 2 (3 Menos vendidos):
# Producto
# Cubo mágico 8x8       643600.0
# Dinosaurio Rex        770300.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

stores = df_most_sold['Tienda'].unique()

fig, axes = plt.subplots(len(stores), 1, figsize=(3, 3 * len(stores)), sharex=False)
fig.suptitle('Top 3 Productos Más Vendidos por Tienda', y=1.02, fontsize=16)

for i, store_name in enumerate(stores):
    data_store = df_most_sold[df_most_sold['Tienda'] == store_name]
    sns.barplot(x='Producto', y='Ventas', data=data_store, palette='viridis', ax=axes[i], hue='Producto', legend=False)
    axes[i].set_title(f'{store_name}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Ventas (COP)')
    axes[i].ticklabel_format(style='plain', axis='y')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(len(stores), 1, figsize=(3, 3 * len(stores)), sharex=False)
fig.suptitle('Top 3 Productos Menos Vendidos por Tienda', y=1.02, fontsize=16)

for i, store_name in enumerate(stores):
    data_store = df_least_sold[df_least_sold['Tienda'] == store_name]
    sns.barplot(x='Producto', y='Ventas', data=data_store, palette='magma', ax=axes[i], hue='Producto', legend=False)
    axes[i].set_title(f'{store_name}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Ventas (COP)')
    axes[i].ticklabel_format(style='plain', axis='y')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio_tienda1 = tienda['Costo de envío'].mean()
envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

# %%
print(f"Costo de envío promedio Tienda 1: {envio_promedio_tienda1:.2f}")
print(f"Costo de envío promedio Tienda 2: {envio_promedio_tienda2:.2f}")
print(f"Costo de envío promedio Tienda 3: {envio_promedio_tienda3:.2f}")
print(f"Costo de envío promedio Tienda 4: {envio_promedio_tienda4:.2f}")
# Out:
# Costo de envío promedio Tienda 1: 26018.61
# Costo de envío promedio Tienda 2: 25216.24
# Costo de envío promedio Tienda 3: 24805.68
# Costo de envío promedio Tienda 4: 23459.46

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

envios_promedio = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costo de Envío Promedio': [envio_promedio_tienda1, envio_promedio_tienda2,
                                envio_promedio_tienda3, envio_promedio_tienda4]
})

plt.figure(figsize=(8, 5))
sns.barplot(x='Tienda', y='Costo de Envío Promedio', data=envios_promedio, palette='Blues_d')
plt.title('Costo de Envío Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Costo de Envío Promedio (COP)')
plt.ticklabel_format(style='plain', axis='y')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2094406350.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tienda', y='Costo de Envío Promedio', data=envios_promedio, palette='Blues_d')

# %% [markdown]
# # **Resumen Final**

# %% [markdown]
# # Informe Final: Recomendación de Tienda para el Sr. Juan
#
# ## Análisis Detallado
#
# ### 1. Ingresos Totales por Tienda
# El primer indicador analizado fue el ingreso total generado por cada tienda, un factor crucial para determinar el volumen de ventas general:
#
# *   **Tienda 1:** 1,150,880,400.00 COP
# *   **Tienda 2:** 1,116,343,500.00 COP
# *   **Tienda 3:** 1,098,019,600.00 COP
# *   **Tienda 4:** 1,038,375,700.00 COP
#
# La **Tienda 1** lidera en ingresos totales, lo que sugiere que tiene el mayor volumen de transacciones o un valor promedio de venta más alto, indicando un mercado potencialmente más grande o más activo.
#
# ### 2. Ventas por Categoría de Producto
# Se examinaron las ventas por categoría para entender qué tipos de productos tienen mayor demanda en cada tienda. Las categorías 'Electrónicos' y 'Electrodomésticos' muestran consistentemente los mayores ingresos en todas las tiendas. Específicamente:
#
# *   **Tienda 1** y **Tienda 2** muestran un desempeño muy fuerte en 'Electrónicos' y 'Electrodomésticos', lo que las convierte en puntos de venta atractivos si los productos del Sr. Juan pertenecen a estas categorías.
# *   La **Tienda 3** también tiene un buen rendimiento en estas categorías, mientras que la **Tienda 4** muestra cifras ligeramente menores en 'Electrodomésticos' en comparación con las otras.
#
# ### 3. Calificación Promedio de los Clientes
# La satisfacción del cliente es vital. Las calificaciones promedio de cada tienda son:
#
# *   **Tienda 1:** 3.98
# *   **Tienda 2:** 4.04
# *   **Tienda 3:** 4.05 (La más alta)
# *   **Tienda 4:** 4.00
#
# La **Tienda 3** tiene la calificación promedio más alta, lo que indica un nivel superior de satisfacción del cliente. La **Tienda 1**, aunque no es la más alta, mantiene una calificación sólida, lo cual es positivo.
#
# ### 4. Productos Más y Menos Vendidos
# Al analizar los productos más y menos vendidos en cada tienda, se observa un patrón general:
#
# *   **Productos Más Vendidos:** Productos como 'TV LED UHD 4K', 'Iphone 15' y 'Refrigerador' son consistentemente los de mayor venta en todas las tiendas, lo que sugiere una fuerte demanda para artículos de tecnología y electrodomésticos de alto valor.
# *   **Productos Menos Vendidos:** Productos como 'Cuerda para saltar', 'Dinosaurio Rex' y 'Cubo mágico 8x8' aparecen repetidamente entre los menos vendidos en todas las tiendas. Si los productos del Sr. Juan son de nicho similar, estas tiendas podrían no ser las más adecuadas.
#
# ### 5. Costo de Envío Promedio
# Los costos de envío pueden impactar la rentabilidad del Sr. Juan. Los promedios son:
#
# *   **Tienda 1:** 26,018.61 COP
# *   **Tienda 2:** 25,216.24 COP
# *   **Tienda 3:** 24,805.68 COP
# *   **Tienda 4:** 23,459.46 COP (El más bajo)
#
# La **Tienda 4** presenta el costo de envío promedio más bajo, lo cual podría ser una ventaja si los productos del Sr. Juan tienen márgenes ajustados o son voluminosos/pesados, aunque su ingreso total es el menor.
#
# ## Conclusión y Recomendación
#
# Considerando todos los factores analizados, la **Tienda 1** emerge como la opción más prometedora para el Sr. Juan. Aquí la justificación:
#
# 1.  **Mayor Potencial de Mercado:** La Tienda 1 tiene los ingresos totales más altos, lo que indica una base de clientes más grande y un mayor volumen de transacciones. Esto se traduce en una mayor visibilidad y oportunidad de ventas para los productos del Sr. Juan.
# 2.  **Consistencia en Categorías Clave:** Dada la alta demanda en categorías como 'Electrónicos' y 'Electrodomésticos' (donde sus productos podrían encajar si son de ese rubro), la Tienda 1 ha demostrado ser muy efectiva en la venta de estos artículos, lo que podría beneficiar la introducción de nuevos productos similares.
# 3.  **Calificación del Cliente Sólida:** Aunque no tiene la calificación más alta, su promedio de 3.98 es muy respetable, lo que sugiere que los clientes están generalmente satisfechos con su experiencia de compra. Esto es importante para mantener la reputación de los productos del Sr. Juan.
# 4.  **Menos sensible al costo de envío:** Aunque la Tienda 4 tiene el costo de envío más bajo, la diferencia no es lo suficientemente grande como para superar la ventaja en ingresos totales de la Tienda 1. La mayor base de clientes de la Tienda 1 podría compensar fácilmente cualquier ligera diferencia en el costo de envío.
#
# En resumen, la **Tienda 1** ofrece el mejor equilibrio entre un alto volumen de ventas y una buena reputación de cliente, lo que la convierte en la opción más estratégica para el Sr. Juan para maximizar su alcance y beneficios.
#
# Por lo tanto, la **Tienda 4**, es la que peor resultado en ventas tiene de igual manera no resulta destacable en ingun otro aspecto, si bien tiene una buena calificación por parte de los clientes, no resulta destacable como para poderseguir siendo la mas rentable. Esta puede cerrarse y enfocar el gasto que impone en otras sucursales que generan mejor rendimiento.
